# %% [markdown]
# <a href="https://colab.research.google.com/github/loup1731/IA_2023-1/blob/main/P_G3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
X = data[['lstat']]
y = data['medv']
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
r2 = r2_score(y_test, y_pred)
print('Coeficiente de determinación (R^2):', r2)
plt.scatter(X_test[:,1], y_test)
plt.plot(X_test[:,1], y_pred, color='red')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()
# Out:
# Coeficiente de determinación (R^2): 0.5428594395609442
